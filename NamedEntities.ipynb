# %%
import spacy

# %%
nlp = spacy.load("en_core_web_md")

# %%
from docx import Document

# %%
document = Document('Linss-Lukas-ba.docx')

# %%
paragraphs = document.paragraphs
text = ''

for i, p in enumerate(paragraphs):
    if len(p.text) > 100:
        text += p.text

# %%
doc = nlp(text)

# %%
for ent in doc.ents: 
    print(ent.text, ent.label_)
# Out:
# Brands ORG
# almost 50 years DATE
# eight CARDINAL
# 145 CARDINAL
# the first three weeks DATE
# one CARDINAL
# Facebook ORG
# Meta ORG
# the past years DATE
# Google ORG
# early days DATE
# the past decade DATE
# two CARDINAL
# Firstly ORDINAL
# today DATE
# Worldline ORG
# first ORDINAL
# the year 1992 DATE
# Neal Stephenson PERSON
# Snow Crash WORK_OF_ART
# three CARDINAL
# the 1970s DATE
# first ORDINAL
# Second Life ORG
# 2003 DATE
# these early days DATE
# Roblox ORG
# 150 million CARDINAL
# monthly DATE
# MAU ORG
# Today DATE
# virtual & ORG
# Nike ORG
# Gucci PRODUCT
# today DATE
# five CARDINAL
# AR GPE
# VR ORG
# MUD PRODUCT
# the 1970s DATE
# five CARDINAL
# the 1970s DATE
# the present day DATE
# five CARDINAL
# first ORDINAL
# Second Life ORG
# 2003 DATE
# Linden Lab ORG
# USD 500 million MONEY
# the year 2015 DATE
# fifth ORDINAL
# Dionisio et al PERSON
# MetaWorlds ORG
# MetaGalaxies PRODUCT
# MetaWorlds ORG
# Galaxies ORG
# VR ORG
# AR GPE
# Dwivedi et al PERSON
# VR ORG
# VR ORG
# today DATE
# Components WORK_OF_ART
# Lee et al PERSON
# 14 CARDINAL
# 1 CARDINAL
# Duan et al PERSON
# OSI ORG
# OSI ORG
# OSI ORG
# 1 CARDINAL
# today DATE
# today DATE
# Unity ORG
# Unity Technologies ORG
# Unreal ORG
# Epic Games ORG
# Unity Technologies ORG
# Epic Games ORG
# two CARDINAL
# Reality-Virtuality Continuum ORG
# VR GPE
# VR ORG
# VR ORG
# AR GPE
# XR ORG
# Mixed Reality ORG
# AR GPE
# VR GPE
# VR ORG
# FOV ORG
# VR ORG
# FOV ORG
# 200° x QUANTITY
# 130° QUANTITY
# at least 6 CARDINAL
# VR ORG
# first ORDINAL
# the Bitcoin Network ORG
# two CARDINAL
# Decentraland ORG
# Cryptovoxels NORP
# Ethereum ORG
# Decentraland ORG
# Autonomous Organization ORG
# One CARDINAL
# Second Life ORG
# Roblox PERSON
# Decentraland ORG
# Sandbox ORG
# the last two years DATE
# one CARDINAL
# four CARDINAL
# two CARDINAL
# 2D ORG
# Two CARDINAL
# Gather Town FAC
# VR ORG
# AR GPE
# Acceleration Studios ORG
# two CARDINAL
# 4 CARDINAL
# 2 CARDINAL
# two CARDINAL
# four CARDINAL
# Mirror Worlds ORG
# Virtual Worlds ORG
# Barnes ORG
# 2019 DATE
# 19 CARDINAL
# de Regt ORG
# Barnes ORG
# 20, 2019 DATE
# Hofman-Kohlmeyer ORG
# 2017 DATE
# 176 CARDINAL
# Martínez-Navarro PERSON
# 2019 DATE
# 475 CARDINAL
# Lee et al. PERSON
# 2021 DATE
# 34 CARDINAL
# VR ORG
# Xi PERSON
# Hamari PERSON
# 2021 DATE
# 46 CARDINAL
# VR ORG
# AR GPE
# Shen et al. PERSON
# 2021 DATE
# 3 CARDINAL
# VR ORG
# VR ORG
# Martínez-Navarro PERSON
# 2019 DATE
# 476 CARDINAL
# de Regt ORG
# Barnes ORG
# 2019 DATE
# 21-22 CARDINAL
# ERC721 ORG
# Momtaz PERSON
# 2022 DATE
# 228 CARDINAL
# Xi PERSON
# Hamari PERSON
# 2021 DATE
# 37 CARDINAL
# de Regt ORG
# Barnes ORG
# 2019 DATE
# 20 CARDINAL
# Hofman-Kohlmeyer ORG
# 2017 DATE
# 178 CARDINAL
# Martínez-Navarro PERSON
# 2019 DATE
# 476 CARDINAL
# Martínez-Navarro PERSON
# 2019 DATE
# 481 CARDINAL
# Xi PERSON
# Hamari PERSON
# 2021 DATE
# 37 CARDINAL
# Business to Consumer ORG
# Business to Business ORG
# two CARDINAL
# two CARDINAL
# Buhalis NORP
# VR ORG
# AR ORG
# Second Life ORG
# the mid to late 2000s DATE
# the last decade DATE
# Xi PERSON
# Hamari PERSON
# 72 CARDINAL
# 37.35 % PERCENT
# 16.87 % PERCENT
# 16.87 % PERCENT
# 4.82% PERCENT
# 30.12 % PERCENT
# 20.48 % PERCENT
# 14.48 % PERCENT
# 65.05 % PERCENT
# only 14.43 % PERCENT
# British NORP
# only 25 % PERCENT
# 200 MONEY
# 30 % PERCENT
# 15 MONEY
# 80 MONEY
# 20 % PERCENT
# five CARDINAL
# one CARDINAL
# 2019 DATE
# two CARDINAL
# Vividness CARDINAL
# Cummings ORG
# Bailenson ORG
# two CARDINAL
# Wu et al PERSON
# 170 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# three CARDINAL
# 27 CARDINAL
# Second Life ORG
# Hassouneh GPE
# Brengman ORG
# 9 CARDINAL
# two CARDINAL
# 18-34 DATE
# Shen et al PERSON
# 15 CARDINAL
# 5 CARDINAL
# 5 CARDINAL
# first ORDINAL
# One CARDINAL
# American NORP
# Nike ORG
# NIKELAND ORG
# Roblox PERSON
# September of 2021 DATE
# over 31 million CARDINAL
# NIKELAND ORG
# Nike ORG
# Nike ORG
# Nike ORG
# Three months DATE
# NIKELAND ORG
# Nike ORG
# RTFKT ORG
# Nike ORG
# between USD 248 MONEY
# NFT ORG
# OpenSea ORG
# Nike ORG
# Brand ORG
# April 2021 DATE
# Vans ORG
# Vans World ORG
# Roblox PERSON
# over 92 million CARDINAL
# NIKELAND ORG
# Vans World ORG
# Italian NORP
# Gucci PRODUCT
# 2021 DATE
# Gucci Garden FAC
# 2 weeks DATE
# Roblox PERSON
# 1.20 MONEY
# 9 CARDINAL
# one CARDINAL
# 4,115 MONEY
# 715 CARDINAL
# Gucci Vault PRODUCT
# Sandbox ORG
# Korean NORP
# Samsung ORG
# 837X CARDINAL
# Decentraland LOC
# January of 2022 DATE
# Samsung ORG
# 837 CARDINAL
# New York City GPE
# German NORP
# Deka PERSON
# Decentraland LOC
# ING ORG
# Roblox PERSON
# Companies ORG
# Nike ORG
# Gucci ORG
# second ORDINAL
# 3 CARDINAL
# 2 CARDINAL
# three CARDINAL
# 3 CARDINAL
# three CARDINAL
# 2D ORG
# GPU ORG
# 3 CARDINAL
# Realtime Interactive Systems ORG
# RIS ORG
# RIS ORG
# RIS ORG
# Wiebusch PERSON
# Latoschik PERSON
# RIS ORG
# RIS ORG
# Unity3D ORG
# RIS ORG
# ECS ORG
# Unity3D ORG
# Decentraland ORG
# 6 CARDINAL
# ECS ORG
# ECS ORG
# one CARDINAL
# ECS ORG
# ECS ORG
# section 2.2.3 LAW
# Roblox PERSON
# Decentraland ORG
# today DATE
# Roblox PERSON
# Decentraland GPE
# Second Life ORG
# Spatial ORG
# Fortnite ORG
# UGC ORG
# UGC ORG
# today DATE
# Counter Strike and Defence ORG
# 2 CARDINAL
# UGC ORG
# UGC ORG
# UGC ORG
# UGC ORG
# UGC ORG
# third ORDINAL
# UGC ORG
# UGC ORG
# Roblox Studio ORG
# Decentraland ORG
# UGC ORG
# IVWP ORG
# Matthew Ball PERSON
# The Metaverse WORK_OF_ART
# Ball PERSON
# IVWP ORG
# Roblox PERSON
# UGC ORG
# three-month DATE
# Worldline ORG
# Worldline SA ORG
# French NORP
# Worldline ORG
# Worldline Showroom ORG
# Decentraland LOC
# Worldline ORG
# Worldline ORG
# 2022 DATE
# McKinsey PERSON
# daily DATE
# NFT ORG
# around USD 250 million MONEY
# Roblox PERSON
# USD 14 billion MONEY
# 2018-2020 DATE
# third ORDINAL
# Worldline ORG
# two-month DATE
# January 2023 DATE
# March 2023 DATE
# four CARDINAL
# two CARDINAL
# 15 CARDINAL
# Decentraland LOC
# Roblox PERSON
# Decentraland ORG
# Decentraland ORG
# Decentraland ORG
# Decentraland LOC
# Ethereum ORG
# Decentraland ORG
# 15 CARDINAL
# eight CARDINAL
# Decentraland LOC
# 64x32 metre QUANTITY
# Decentraland Land ORG
# 2.490 - 7.000.000 MONEY
# 0.521 CARDINAL
# five CARDINAL
# four CARDINAL
# first ORDINAL
# three CARDINAL
# Osterwalder PERSON
# Worldline ORG
# worldlines virtual mall ORG
# Worldline ORG
# AR GPE
# VR ORG
# Worldline ORG
# LinkedIn ORG
# Worldline ORG
# Worldline ORG
# first ORDINAL
# Worldline ORG
# Worldline ORG
# Decentraland LOC
# three CARDINAL
# 8 CARDINAL
# first ORDINAL
# one CARDINAL
# weekly DATE
# nine CARDINAL
# Worldline ORG
# first ORDINAL
# 10 CARDINAL
# nine CARDINAL
# Decentraland LOC
# TypeScript ORG
# TypeScript ORG
# JavaScript PRODUCT
# Microsoft ORG
# TypeScript ORG
# JavaScript ORG
# JavaScript ORG
# TypeScript ORG
# JavaScript PRODUCT
# TypeScript ORG
# two CARDINAL
# TypeScript ORG
# TypeScript ORG
# TypeScript ORG
# Unity ORG
# Decentraland ORG
# SDK ORG
# Decentraland ORG
# Decentraland LOC
# TypeScript ORG
# SDK ORG
# the Decentraland SDK LOC
# the Visual Studio Code ORG
# VS Code ORG
# Decentraland ORG
# Decentraland Editor ORG
# the VS Code LAW
# VS Code PRODUCT
# Decentraland ORG
# Blender ORG
# Blender ORG
# Blender ORG
# Decimate ORG
# Blender ORG
# Blender ORG
# Blender ORG
# the Decentraland Awesome Repository ORG
# The Awesome Repository ORG
# Decentraland ORG
# Decentraland LOC
# Decentraland LOC
# at least one CARDINAL
# section 3.2.3 LAW
# five CARDINAL
# Shen et al PERSON
# 15 CARDINAL
# European NORP
# North America LOC
# Asia LOC
# Oceania LOC
# Decentraland LOC
# Decentraland ORG
# 4 CARDINAL
# two CARDINAL
# second ORDINAL
# GPU ORG
# Decentraland ORG
# one CARDINAL
# Shen et al PERSON
# first ORDINAL
# Decentraland LOC
# 9 CARDINAL
# four CARDINAL
# five CARDINAL
# three to four CARDINAL
# 10 CARDINAL
# Decentraland LOC
# Decentralands PRODUCT
# 2D CARDINAL
# five CARDINAL
# seven CARDINAL
# four CARDINAL
# three CARDINAL
# two CARDINAL
# API ORG
# Decentraland LOC
# the geoPlugin API PRODUCT
# API ORG
# 10 CARDINAL
# API ORG
# API ORG
# up to four CARDINAL
# Decentraland ORG
# the Decentraland Awesome Repository ORG
# UML ORG
# 12 CARDINAL
# SubScene PERSON
# SubScenes LOC
# two CARDINAL
# first ORDINAL
# SubScene PERSON
# EntityWrapper ORG
# 11 CARDINAL
# EntityWrapper PERSON
# SubScene PERSON
# almost 70 % PERCENT
# up to 15 CARDINAL
# ten CARDINAL
# five CARDINAL
# two CARDINAL
# Worldlines ORG
# Saferpay PERSON
# Saferpay PERSON
# Saferpay PERSON
# Worldline ORG
# Decentralands ORG
# Decentraland LOC
# SDK ORG
# Transak PERSON
# Worldline ORG
# Decentraland ORG
# weekly DATE
# weekly DATE
# the previous week's DATE
# third ORDINAL
# Decentraland ORG
# Decentraland LOC
# GitLab ORG
# almost two and a half months CARDINAL
# the eighth of March 2023 DATE
# Decentraland LOC
# three CARDINAL
# nine CARDINAL
# nine CARDINAL
# eight CARDINAL
# one CARDINAL
# Worldline ORG
# first ORDINAL
# two CARDINAL
# three CARDINAL
# four CARDINAL
# six CARDINAL
# 6 CARDINAL
# 50 CARDINAL
# Worldline ORG
# Australian NORP
# Naked Life ORG
# European NORP
# five CARDINAL
# eight CARDINAL
# Switzerland GPE
# Germany GPE
# 7 CARDINAL
# six CARDINAL
# nine CARDINAL
# four CARDINAL
# SNGLR ORG
# six CARDINAL
# seven CARDINAL
# three CARDINAL
# six CARDINAL
# four CARDINAL
# two CARDINAL
# two CARDINAL
# four CARDINAL
# SNGLR ORG
# eight CARDINAL
# nine CARDINAL
# only two CARDINAL
# eight CARDINAL
# more than 50 % PERCENT
# only one CARDINAL
# eight CARDINAL
# 7 CARDINAL
# Worldline ORG
# 8 CARDINAL
# the first three weeks DATE
# the first three weeks DATE
# 145 CARDINAL
# weekly DATE
# 48 CARDINAL
# the launch week DATE
# the following weeks DATE
# the initial launch week DATE
# the three weeks DATE
# fifteen CARDINAL
# an average of TIME
# nineteen minutes TIME
# 49 % PERCENT
# 51% PERCENT
# 95 % PERCENT
# Decentraland ORG
# only 5% PERCENT
# Worldline ORG
# first ORDINAL
# Worldline ORG
# 19 minutes TIME
# Decentraland LOC
# Decentraland LOC
# ECS ORG
# the Decentraland SDK LOC
# Decentraland ORG
# SDK ORG
# Decentraland LOC
# the Awesome Repository ORG
# Decentraland Discord ORG
# Blender ORG
# Decentraland LOC
# VR ORG
# Roblox PERSON
# Decentraland ORG
# Decentraland PRODUCT
# Decentraland ORG
# eight CARDINAL
# up to 22 minutes TIME
# only 145 CARDINAL
# the first three weeks DATE
# Shopping Experiences in the Metaverse – Implementation of a White Label Metaverse Solution WORK_OF_ART
# three-month DATE
# Worldline ORG
# monthly DATE
# one CARDINAL
# the first month DATE
# Shopping Experiences in the Metaverse – Implementing a White Label Metaverse Solution WORK_OF_ART

# %%
named_ents_dic = {}
for ent in doc.ents:
    if ent.label_ in named_ents_dic:
        named_ents_dic[ent.label_] += 1
    else:
        named_ents_dic[ent.label_] = 1

# %%
sorted_ents_dic = {k: v for k, v in sorted(named_ents_dic.items(), key=lambda item: item[1], reverse=True)}
print(sorted_ents_dic)
# Out:
# {'ORG': 231, 'CARDINAL': 157, 'DATE': 73, 'PERSON': 50, 'LOC': 28, 'ORDINAL': 20, 'PERCENT': 18, 'GPE': 14, 'PRODUCT': 11, 'NORP': 11, 'MONEY': 10, 'WORK_OF_ART': 5, 'TIME': 4, 'QUANTITY': 3, 'LAW': 3, 'FAC': 2}

# %%
from spacy import displacy
displacy.render(doc, style='ent')

# %%
import pandas as pd

data = {'Named Entities': list(sorted_ents_dic.keys()),
        'Found in Document' : list(sorted_ents_dic.values())
        }

df = pd.DataFrame(data=data)

# %%
print(df.head())
# Out:
#   Named Entities  Found in Document
# 0            ORG                231
# 1       CARDINAL                157
# 2           DATE                 73
# 3         PERSON                 50
# 4            LOC                 28

# %%
total_entities = df['Found in Document'].sum()
percentage = [x / total_entities for x in df['Found in Document'].tolist()]
df['Percentage'] = percentage

# %%
data = [spacy.explain(ent) for ent in df['Named Entities'].tolist()]
df.insert(1, 'Definition', data)

# %%
df.to_excel('Named_Entities.xlsx')
